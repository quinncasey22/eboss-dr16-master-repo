# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import os 
from astropy import units as u
from specutils import Spectrum1D, SpectralRegion
from specutils.manipulation import SplineInterpolatedResampler
import scipy.signal

# %%
path = '/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less'

# %%
for root, directories, files in os.walk(path, topdown=False):

    for name in files:
        print(os.path.join(root, name))
# Out:
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/11312/spec-11312-58433-0676.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6754/spec-6754-56414-0984.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3817/spec-3817-55277-0677.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3674/spec-3674-55182-0551.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4836/spec-4836-55689-0781.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4624/spec-4624-55654-0471.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/5960/spec-5960-56097-0943.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6000/spec-6000-56102-0635.fits
# /Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3783/spec-3783-55246-0882.fits
# ...

# %%
def smooth_spec(lamb, fluxhat):

    #Smoothed spectra
    plt.style.use('grayscale')
    f, ax = plt.subplots(figsize=(12, 6)) 
    plt.xlabel('R-Frame Wavelength ($\AA$)')
    plt.ylabel('erg/s/$cm^2$/Ang')
    plt.title(plate)
    ax.step(lamb[np.where(snr > 1)], fluxhat[np.where(snr > 1)], c='k')
    
    return

# %%
f1 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/11312/spec-11312-58433-0676.fits')
f2 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6754/spec-6754-56414-0984.fits')
f3 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3817/spec-3817-55277-0677.fits')
f4 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3674/spec-3674-55182-0551.fits')
f5 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4836/spec-4836-55689-0781.fits')
f6 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4624/spec-4624-55654-0471.fits')
f7 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/5960/spec-5960-56097-0943.fits')
f8 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6000/spec-6000-56102-0635.fits')
f9 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/3783/spec-3783-55246-0882.fits')
f10 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6431/spec-6431-56311-0846.fits')
f11 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4395/spec-4395-55828-0415.fits')
f12 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/7303/spec-7303-57013-0321.fits')
f13 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6670/spec-6670-56389-0169.fits')
f14 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6840/spec-6840-56685-0166.fits')
f15 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/5064/spec-5064-55864-0237.fits')
f16 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4603/spec-4603-55999-0679.fits')
f17 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4604/spec-4604-55983-0433.fits')
f18 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4628/spec-4628-55646-0103.fits')
f19 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/5700/spec-5700-56245-0477.fits')
f20 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/6663/spec-6663-56338-0205.fits')
f21 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/5872/spec-5872-56027-0469.fits')
f22 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.4-bin/0.4-spec-files-less/4763/spec-4763-55869-0148.fits')

# %%
plate = '11312-58433-0676'
z = f1[2].data['z']
lamb = (10**f1[1].data['loglam']* u.AA)/(1+z)
flux = f1[1].data['flux']
err = np.sqrt(1/f1[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6754-56414-0984'
z = f2[2].data['z']
lamb = (10**f2[1].data['loglam']* u.AA)/(1+z)
flux = f2[1].data['flux']
err = np.sqrt(1/f2[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '3817-55277-0677'
z = f3[2].data['z']
lamb = (10**f3[1].data['loglam']* u.AA)/(1+z)
flux = f3[1].data['flux']
err = np.sqrt(1/f3[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '3674-55182-0551'
z = f4[2].data['z']
lamb = (10**f4[1].data['loglam']* u.AA)/(1+z)
flux = f4[1].data['flux']
err = np.sqrt(1/f4[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4836-55689-0781'
z = f5[2].data['z']
lamb = (10**f5[1].data['loglam']* u.AA)/(1+z)
flux = f5[1].data['flux']
err = np.sqrt(1/f5[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4624-55654-0471'
z = f6[2].data['z']
lamb = (10**f6[1].data['loglam']* u.AA)/(1+z)
flux = f6[1].data['flux']
err = np.sqrt(1/f6[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '5960-56097-0943'
z = f7[2].data['z']
lamb = (10**f7[1].data['loglam']* u.AA)/(1+z)
flux = f7[1].data['flux']
err = np.sqrt(1/f7[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6000-56102-0635'
z = f8[2].data['z']
lamb = (10**f8[1].data['loglam']* u.AA)/(1+z)
flux = f8[1].data['flux']
err = np.sqrt(1/f8[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '3783-55246-0882'
z = f9[2].data['z']
lamb = (10**f9[1].data['loglam']* u.AA)/(1+z)
flux = f9[1].data['flux']
err = np.sqrt(1/f9[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6431-56311-0846'
z = f10[2].data['z']
lamb = (10**f10[1].data['loglam']* u.AA)/(1+z)
flux = f10[1].data['flux']
err = np.sqrt(1/f10[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4395-55828-0415'
z = f11[2].data['z']
lamb = (10**f11[1].data['loglam']* u.AA)/(1+z)
flux = f11[1].data['flux']
err = np.sqrt(1/f11[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '7303-57013-0321'
z = f12[2].data['z']
lamb = (10**f12[1].data['loglam']* u.AA)/(1+z)
flux = f12[1].data['flux']
err = np.sqrt(1/f12[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6670-56389-0169'
z = f13[2].data['z']
lamb = (10**f13[1].data['loglam']* u.AA)/(1+z)
flux = f13[1].data['flux']
err = np.sqrt(1/f13[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6840-56685-0166'
z = f14[2].data['z']
lamb = (10**f14[1].data['loglam']* u.AA)/(1+z)
flux = f14[1].data['flux']
err = np.sqrt(1/f14[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '5064-55864-0237'
z = f15[2].data['z']
lamb = (10**f15[1].data['loglam']* u.AA)/(1+z)
flux = f15[1].data['flux']
err = np.sqrt(1/f15[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4603-55999-0679'
z = f16[2].data['z']
lamb = (10**f16[1].data['loglam']* u.AA)/(1+z)
flux = f16[1].data['flux']
err = np.sqrt(1/f16[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4604-55983-0433'
z = f17[2].data['z']
lamb = (10**f17[1].data['loglam']* u.AA)/(1+z)
flux = f17[1].data['flux']
err = np.sqrt(1/f17[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4628-55646-0103'
z = f18[2].data['z']
lamb = (10**f18[1].data['loglam']* u.AA)/(1+z)
flux = f18[1].data['flux']
err = np.sqrt(1/f18[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '5700-56245-0477'
z = f19[2].data['z']
lamb = (10**f19[1].data['loglam']* u.AA)/(1+z)
flux = f19[1].data['flux']
err = np.sqrt(1/f19[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '6663-56338-0205'
z = f20[2].data['z']
lamb = (10**f20[1].data['loglam']* u.AA)/(1+z)
flux = f20[1].data['flux']
err = np.sqrt(1/f20[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '5872-56027-0469'
z = f21[2].data['z']
lamb = (10**f21[1].data['loglam']* u.AA)/(1+z)
flux = f21[1].data['flux']
err = np.sqrt(1/f21[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
plate = '4763-55869-0148'
z = f22[2].data['z']
lamb = (10**f22[1].data['loglam']* u.AA)/(1+z)
flux = f22[1].data['flux']
err = np.sqrt(1/f22[1].data['ivar'])

snr = flux/err
flux = flux *10**-17* u.Unit('erg cm-2 s-1 AA-1')
fluxhat = scipy.signal.medfilt(flux)

smooth_spec(lamb, fluxhat)
# Out:
# /Users/quinncasey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
